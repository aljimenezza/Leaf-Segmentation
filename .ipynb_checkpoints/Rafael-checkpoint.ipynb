# %%
from plantcv import plantcv as pcv
import numpy as np
from PIL import Image
from matplotlib import pyplot as plt
import cv2

# %%
#edges2, np.max(edges2)

# %%
img = Image.open('DataSet/train/LEAF_0225.jpg').convert('RGBA')
arr = np.array(img)

# %%
pcv.params.debug = "print"
img = plt.imread('DataSet/train/LEAF_0473.jpg')
img
edges = pcv.canny_edge_detect(img)
edges2 = pcv.canny_edge_detect(img=img, high_thresh=50, low_thresh =40, sigma=1)
#edges2
plt.imshow(edges2, interpolation='nearest')
plt.show()
